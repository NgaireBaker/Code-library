# %%
from ucimlrepo import fetch_ucirepo
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/167.0 kB ? eta -:--:--
#      ---- -------------------------------- 20.5/167.0 kB 640.0 kB/s eta 0:00:01
#      -------------------------------- ----- 143.4/167.0 kB 2.1 MB/s eta 0:00:01
#      -------------------------------------- 167.0/167.0 kB 1.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.2/7.8 MB 14.1 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/7.8 MB 6.3 MB/s eta 0:00:02
#    --- ------------------------------------ 0.7/7.8 MB 5.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/7.8 MB 5.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/7.8 MB 5.1 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/7.8 MB 5.0 MB/s eta 0:00:02
#    -------- ------------------------------- 1.6/7.8 MB 5.1 MB/s eta 0:00:02
# ...

# %%
# fetch dataset 
abalone = fetch_ucirepo(id=1)

# %%
rings = y

# %%
# data (as pandas dataframes) 
X = abalone.data.features 
y = X["Sex"]

# %%
X = X.drop("Sex", axis=1)

# %%
X["Rings"] = rings

# %%
X
# Out:
#       Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell_weight  Rings
# ...

# %%
y
# Out:
# 0       M
# 1       M
# 2       F
# 3       M
# 4       I
#        ..
# 4172    F
# 4173    M
# 4174    M
# 4175    F
# 4176    M
# Name: Sex, Length: 4177, dtype: object

# %%
  
# metadata 
print(abalone.metadata)
# Out:
# {'uci_id': 1, 'name': 'Abalone', 'repository_url': 'https://archive.ics.uci.edu/dataset/1/abalone', 'data_url': 'https://archive.ics.uci.edu/static/public/1/data.csv', 'abstract': 'Predict the age of abalone from physical measurements', 'area': 'Biology', 'tasks': ['Classification', 'Regression'], 'characteristics': ['Tabular'], 'num_instances': 4177, 'num_features': 8, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': [], 'target_col': ['Rings'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1994, 'last_updated': 'Mon Aug 28 2023', 'dataset_doi': '10.24432/C55C7W', 'creators': ['Warwick Nash', 'Tracy Sellers', 'Simon Talbot', 'Andrew Cawthorn', 'Wes Ford'], 'intro_paper': None, 'additional_info': {'summary': 'Predicting the age of abalone from physical measurements.  The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -
# ...

# %%
y
# Out:
#       Rings
# 0        15
# 1         7
# 2         9
# 3        10
# 4         7
# ...     ...
# 4172     11
# 4173     10
# 4174      9
# 4175     10
# 4176     12
#
# [4177 rows x 1 columns]

# %%
# variable information 
print(abalone.variables)
# Out:
#              name     role         type demographic  \
# 0             Sex  Feature  Categorical        None
# 1          Length  Feature   Continuous        None
# 2        Diameter  Feature   Continuous        None
# 3          Height  Feature   Continuous        None
# 4    Whole_weight  Feature   Continuous        None
# 5  Shucked_weight  Feature   Continuous        None
# 6  Viscera_weight  Feature   Continuous        None
# 7    Shell_weight  Feature   Continuous        None
# 8           Rings   Target      Integer        None
#
#                    description  units missing_values
# 0         M, F, and I (infant)   None             no
# 1    Longest shell measurement     mm             no
# 2      perpendicular to length     mm             no
# 3           with meat in shell     mm             no
# 4                whole abalone  grams             no
# 5               weight of meat  grams             no
# 6  gut weight (after bleeding)  grams             no
# ...

# %%
data_features = abalone.variables.name.values

# %%
X
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# 3             0.1140        0.1550
# ...

# %%
for feat in data_features:
    try:
        print(f"{feat} mean is: {X[feat].mean()}")
    except:
        print(f"The {feat} doesn't have numerical values")
# Out:
# The Sex doesn't have numerical values
# Length mean is: 0.5239920995930094
# Diameter mean is: 0.40788125448886764
# Height mean is: 0.13951639932966242
# Whole_weight mean is: 0.8287421594445774
# Shucked_weight mean is: 0.35936748862820206
# Viscera_weight mean is: 0.1805936078525257
# Shell_weight mean is: 0.23883085946851804
# Rings mean is: 9.933684462532918

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
male_data = X[y == 'M']

# %%
male_data
# Out:
#       Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 8      0.475     0.370   0.125        0.5095          0.2165          0.1125
# 11     0.430     0.350   0.110        0.4060          0.1675          0.0810
# ...      ...       ...     ...           ...             ...             ...
# 4170   0.550     0.430   0.130        0.8395          0.3155          0.1955
# 4171   0.560     0.430   0.155        0.8675          0.4000          0.1720
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell_weight  Rings
# ...

# %%
average_fields = male_data.mean(numeric_only=True)

# %%
print(average_fields)
# Out:
# Length            0.427746
# Diameter          0.326494
# Height            0.107996
# Whole_weight      0.431363
# Shucked_weight    0.191035
# Viscera_weight    0.092010
# Shell_weight      0.128182
# Rings             7.890462
# dtype: float64

# %%
female_data = X[y == 'F']

# %%
female_data
# Out:
#       Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 6      0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7      0.545     0.425   0.125        0.7680          0.2940          0.1495
# 9      0.550     0.440   0.150        0.8945          0.3145          0.1510
# 10     0.525     0.380   0.140        0.6065          0.1940          0.1475
# ...      ...       ...     ...           ...             ...             ...
# 4160   0.585     0.475   0.165        1.0530          0.4580          0.2170
# 4161   0.585     0.455   0.170        0.9945          0.4255          0.2630
# 4168   0.515     0.400   0.125        0.6150          0.2865          0.1230
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
#
#       Shell_weight  Rings
# ...

# %%
average_fields = female_data.mean(numeric_only=True)

# %%
print(average_fields)
# Out:
# Length            0.427746
# Diameter          0.326494
# Height            0.107996
# Whole_weight      0.431363
# Shucked_weight    0.191035
# Viscera_weight    0.092010
# Shell_weight      0.128182
# Rings             7.890462
# dtype: float64

# %%
infant_data = X[y == 'I']

# %%
average_fields = infant_data.mean(numeric_only=True)

# %%
print(average_fields)
# Out:
# Length            0.427746
# Diameter          0.326494
# Height            0.107996
# Whole_weight      0.431363
# Shucked_weight    0.191035
# Viscera_weight    0.092010
# Shell_weight      0.128182
# Rings             7.890462
# dtype: float64

# %%
def gender_classification(row):
    if row['Length'] < 0.5:
        return 'Infant'
    elif row['Length'] >= 0.5 and row['Rings'] < 7.8:
        return 'Male'
    else:
        return 'Female'

# %%
X.iloc[0,:]
# Out:
# Length             0.4550
# Diameter           0.3650
# Height             0.0950
# Whole_weight       0.5140
# Shucked_weight     0.2245
# Viscera_weight     0.1010
# Shell_weight       0.1500
# Rings             15.0000
# Name: 0, dtype: float64

# %%
for i in range(50):
    print(gender_classification(X.iloc[i,:]))
# Out:
# Infant
# Infant
# Female
# Infant
# Infant
# Infant
# Female
# Female
# Infant
# Female
# Female
# Infant
# Infant
# Female
# Infant
# Female
# Infant
# Infant
# Infant
# Infant
# Infant
# Infant
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Infant
# Female
# Infant
# Female
# Infant
# Infant
# Female
# Infant
# Infant
# Infant
# Infant
# Infant
# Infant
# Infant
# Female

# %%
plt.hist(female_data['Length'], bins=10, color='red', alpha=0.7, edgecolor='black')
plt.hist(male_data['Length'], bins=10, color='blue', alpha=0.7, edgecolor='black') 
plt.hist(infant_data['Length'], bins=10, color='green', alpha=0.7, edgecolor='black')  
plt.title('Histogram of Abalone Length') 
plt.xlabel('Length') 
plt.ylabel('Frequency') 
plt.show()

# %%
plt.hist(female_data['Rings'], bins=10, color='red', alpha=0.7, edgecolor='black') 
plt.hist(male_data['Rings'], bins=10, color='blue', alpha=0.7, edgecolor='black')
plt.hist(infant_data['Rings'], bins=10, color='green', alpha=0.7, edgecolor='black') 
plt.title('Histogram of Abalone Rings') 
plt.xlabel('Rings') 
plt.ylabel('Frequency') 
plt.show()

# %%
def gender_classification2(row):
    if row['Length'] < 0.5:
        return 'Infant'
    elif row['Length'] >= 0.5 <= 0.6 and row['Rings'] > 7 <= 10:
        return 'Male'
    elif row['length'] > 0.6 < 0.9 and row['Rings'] > 10 <25:
        return 'Female'

# %%
for i in range(50):
    print(gender_classification2(X.iloc[i,:]))
# Out:
# Infant
# Infant
# Male
# Infant
# Infant
# Infant
# Male
# Male
# Infant
# Male
# Male
# Infant
# Infant
# Male
# Infant
# Male
# Infant
# Infant
# Infant
# Infant
# Infant
# Infant
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Infant
# Male
# Infant
# Male
# Infant
# Infant
# Male
# Infant
# Infant
# Infant
# Infant
# Infant
# Infant
# Infant
# Male
